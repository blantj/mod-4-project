# %%
import nltk
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split
from matplotlib import cm
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.naive_bayes import MultinomialNB

# %%
sp500 = pd.read_csv('file:///Users/chrisfiorentine/Downloads/data_csv.csv')

# %%
sp500
# Out:
#             Date    SP500  Dividend  Earnings  Consumer Price Index  \
# 0     1871-01-01     4.44      0.26      0.40                 12.46
# 1     1871-02-01     4.50      0.26      0.40                 12.84
# 2     1871-03-01     4.61      0.26      0.40                 13.03
# 3     1871-04-01     4.74      0.26      0.40                 12.56
# 4     1871-05-01     4.86      0.26      0.40                 12.27
# ...          ...      ...       ...       ...                   ...
# 1763  2017-12-01  2664.34     48.93    109.88                246.52
# 1764  2018-01-01  2789.80     49.29       NaN                247.87
# 1765  2018-02-01  2705.16     49.64       NaN                248.99
# 1766  2018-03-01  2702.77     50.00       NaN                249.55
# 1767  2018-04-01  2642.19       NaN       NaN                249.84
#
#       Long Interest Rate  Real Price  Real Dividend  Real Earnings   PE10
# 0                   5.32       89.00           5.21           8.02    NaN
# ...

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1768 entries, 0 to 1767
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1768 non-null   object
#  1   SP500                 1768 non-null   float64
#  2   Dividend              1767 non-null   float64
#  3   Earnings              1764 non-null   float64
#  4   Consumer Price Index  1768 non-null   float64
#  5   Long Interest Rate    1768 non-null   float64
#  6   Real Price            1768 non-null   float64
#  7   Real Dividend         1767 non-null   float64
#  8   Real Earnings         1764 non-null   float64
#  9   PE10                  1648 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 138.2+ KB

# %%
sp500.isnull().describe()
# Out:
#          Date  SP500 Dividend Earnings Consumer Price Index  \
# count    1768   1768     1768     1768                 1768
# unique      1      1        2        2                    1
# top     False  False    False    False                False
# freq     1768   1768     1767     1764                 1768
#
#        Long Interest Rate Real Price Real Dividend Real Earnings   PE10
# count                1768       1768          1768          1768   1768
# unique                  1          1             2             2      2
# top                 False      False         False         False  False
# freq                 1768       1768          1767          1764   1648

# %%
sp500.shape
# Out:
# (1768, 10)

# %%
sp500['date'] = pd.to_datetime(sp500['Date'])

# %%
sp500.set_index('date', inplace = True)

# %%
sp500.drop('Date', axis = 1, inplace = True)

# %%
sp500
# Out:
#               SP500  Dividend  Earnings  Consumer Price Index  \
# date
# 1871-01-01     4.44      0.26      0.40                 12.46
# 1871-02-01     4.50      0.26      0.40                 12.84
# 1871-03-01     4.61      0.26      0.40                 13.03
# 1871-04-01     4.74      0.26      0.40                 12.56
# 1871-05-01     4.86      0.26      0.40                 12.27
# ...             ...       ...       ...                   ...
# 2017-12-01  2664.34     48.93    109.88                246.52
# 2018-01-01  2789.80     49.29       NaN                247.87
# 2018-02-01  2705.16     49.64       NaN                248.99
# 2018-03-01  2702.77     50.00       NaN                249.55
# 2018-04-01  2642.19       NaN       NaN                249.84
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# date
# 1871-01-01                5.32       89.00           5.21           8.02
# ...

# %%
target = sp500['Real Price']

# %%
roll_mean = target.rolling(3).mean()

# %%
fig, ax = plt.subplots(figsize=(13, 10))
ax.plot(target, color='blue',label='Average monthly Real price')
ax.plot(roll_mean, color='red', label='Rolling quarterly mean')
ax.legend()
fig.tight_layout()
